# %%
import librosa
from typing import List, Union, Optional, Tuple, Set
import re
import os
import glob
import numpy as np
import sys

# %%
# the main audio class will create audio objects that will store numpy arrays and sample rates of one or more audio files
# the user can:
    # specify the path to one file
    # specify the path to a folder containing multiple sound files
    # specify a list of paths to multiple individual files or folders containing files
        # everything in a folder will be included by default
        # use a regex string to select specific files in a folder

    # provide a list of files to ignore (none by default)
    # provide a list of folder paths to ignore (everything ignored by default - overrides include)
    # use regex to specify particular name patterns to ignore
 
class Audio:
    
    def __init__(self, include: Union[str, Tuple[str, ...]], exclude: Optional[Union[str, Tuple[str, ...]]] = None, recursive: bool = False) -> None:
        """
        Create new audio object initidalized with a dictionary of audio_samples loaded using files from specified directories
        given include and exclude patterns.

        :param include: A string or tuple of strings specifying the directories or patterns to include.
        :param exclude: A string or set of strings specifying the patterns to exclude.
        :param recursive: Boolean indicating whether to search directories recursively.
        """
        
        self.samples = {}
        self.fetch(include, exclude, recursive)
    
    def fetch(self, include: Union[str, Tuple[str, ...]], exclude: Optional[Union[str, Tuple[str, ...]]] = None, recursive: bool = False, append=False) -> bool:
        """
        Fetch files from specified directories with include and exclude patterns.

        :param include: A string or tuple of strings specifying the directories or patterns to include.
        :param exclude: A string or set of strings specifying the patterns to exclude.
        :param recursive: Boolean indicating whether to search directories recursively.
        :param append: True for adding new files to the existing audio dictionary, or False to overwrite it.
        :return: Boolean value True if all files loaded successfully, False otherwise.
        """
        if isinstance(include, str):
            include = (include,)
            
        if exclude is None:
            exclude = ()
        elif isinstance(exclude, str):
            exclude = (re.compile(exclude),)
        elif isinstance(exclude, tuple):
            try:
                exclude = tuple([re.compile(r) for r in exclude])
            except Exception as e:
                print("Please ensure only strings are used as the exclude patterns.")
                return False

        audio_files = []
        
        for path in include:
            if(self._is_excluded(path, exclude)):
                print(f"{path} matched a pattern in the exclude list and was ignored")
                continue
            if os.path.isdir(path):
                audio_files.extend(self._fetch_from_directory(path, exclude, recursive))
            elif os.path.isfile(path):
                audio_files.append(path)
            else:
                print(f"{path} does not exist or is not a regular file/directory.")
        
        # Clearing the samples dictionary if append = False
        if(not append):
            self.samples.clear()
        
        # check for existence before loading
        for f in audio_files:
            if(f in self.samples.keys()):
                continue
            else:
                try:
                    sample, sr = librosa.load(f)
                    self.samples[f] = [sample, sr]
                except Exception as e:
                    print(f"Error loading {f}: {e}")
                    return False
        
        return True
    
    def _fetch_from_directory(self, directory: str, exclude: Tuple[re.Pattern, ...], recursive: bool) -> List[str]:
        """
        Fetch files from a directory based on include and exclude patterns.

        :param directory: The directory to search.
        :param exclude: Set of regex patterns to exclude.
        :param recursive: Boolean indicating whether to search directories recursively.
        :return: List of file paths.
        """
        
        directory = directory if directory.endswith('/') else (directory + '/')
        extensions = ["*.wav", "*.mp3", "*.flac", "*.ogg", "*.m4a", "*.aac", "*.wma", "*.aiff", "*.au", "*.amr",]  # Supported audio formats
        
        paths = []
        
        if recursive:
            for root, dirs, files in os.walk(directory):
                # Exclude directories early
                dirs[:] = [d for d in dirs if not self._is_excluded(os.path.join(root, d), exclude)]
                for file in files:
                    file_path = os.path.join(root, file)
                    if not self._is_excluded(file_path, exclude) and any(file_path.endswith(ext[1:]) for ext in extensions):
                        paths.append(file_path)
        else:
            for ext in extensions:
                search_pattern = directory + ext
                for path in glob.iglob(search_pattern, recursive=False):
                    if not self._is_excluded(path, exclude):
                        paths.append(path)
                    
        return paths
   
    def _is_excluded(self, file_path: str, exclude: Tuple[re.Pattern, ...]) -> bool:
        """
        Check if a file path matches any of the exclude patterns.

        :param file_path: The file path to check.
        :param exclude: Set of regex patterns to exclude.
        :return: Boolean indicating whether the file path is excluded.
        """
        
        # use regex or regular wildcard expressions for better exclusion matching
        for e in exclude:
            if(e.search(file_path)):
                return True
        return False

    def print(self) -> None:
        if len(self.samples.keys()) != 0:
            count = 0
            print("{")
            for key in self.samples.keys():
                if (count == (len(self.samples.keys())-1) ):
                    print(f"{key} : [ (len={self.samples[key][0].size}, dtype={self.samples[key][0].dtype}, shape={self.samples[key][0].shape}), sample_rate={self.samples[key][1]} ]")
                else:
                    print(f"{key} : [ (len={self.samples[key][0].size}, dtype={self.samples[key][0].dtype}, shape={self.samples[key][0].shape}), sample_rate={self.samples[key][1]} ],")
                count += 1

# %%
audio = Audio("./RAVDESS/", recursive=True, exclude=(r'.*Actor_0[23456789].*', r'.*Actor_[12][0123456789].*' ))

# %%
audio.print()
# Out:
# {
# ./RAVDESS/Actor_01/03-01-04-02-01-01-01.wav : [ (len=83874, dtype=float32, shape=(83874,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-01-01-02-01-01.wav : [ (len=72102, dtype=float32, shape=(72102,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-03-01-02-02-01.wav : [ (len=81667, dtype=float32, shape=(81667,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-04-01-01-02-01.wav : [ (len=78724, dtype=float32, shape=(78724,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-07-01-01-02-01.wav : [ (len=86081, dtype=float32, shape=(86081,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-03-02-02-02-01.wav : [ (len=86817, dtype=float32, shape=(86817,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-07-02-01-02-01.wav : [ (len=90496, dtype=float32, shape=(90496,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-06-01-01-01-01.wav : [ (len=80931, dtype=float32, shape=(80931,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-02-02-02-02-01.wav : [ (len=88289, dtype=float32, shape=(88289,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-04-02-02-01-01.wav : [ (len=82403, dtype=float32, shape=(82403,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-01-01-01-02-01.wav : [ (len=73574, dtype=float32, shape=(73574,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-05-02-02-02-01.wav : [ (len=97853, dtype=float32, shape=(97853,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-02-01-01-02-01.wav : [ (len=79460, dtype=float32, shape=(79460,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-07-01-02-01-01.wav : [ (len=86081, dtype=float32, shape=(86081,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-02-01-01-01-01.wav : [ (len=77988, dtype=float32, shape=(77988,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-08-01-01-01-01.wav : [ (len=75045, dtype=float32, shape=(75045,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-08-02-01-01-01.wav : [ (len=75781, dtype=float32, shape=(75781,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-08-02-01-02-01.wav : [ (len=78724, dtype=float32, shape=(78724,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-06-02-01-01-01.wav : [ (len=110361, dtype=float32, shape=(110361,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-02-02-01-02-01.wav : [ (len=88289, dtype=float32, shape=(88289,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-01-01-02-02-01.wav : [ (len=69895, dtype=float32, shape=(69895,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-07-02-02-02-01.wav : [ (len=96382, dtype=float32, shape=(96382,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-02-01-02-01-01.wav : [ (len=77253, dtype=float32, shape=(77253,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-07-01-01-01-01.wav : [ (len=85345, dtype=float32, shape=(85345,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-05-02-01-01-01.wav : [ (len=90496, dtype=float32, shape=(90496,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-04-02-02-02-01.wav : [ (len=82403, dtype=float32, shape=(82403,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-04-01-02-02-01.wav : [ (len=74310, dtype=float32, shape=(74310,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-04-01-02-01-01.wav : [ (len=77253, dtype=float32, shape=(77253,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-05-01-02-02-01.wav : [ (len=82403, dtype=float32, shape=(82403,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-05-02-01-02-01.wav : [ (len=96382, dtype=float32, shape=(96382,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-06-01-02-02-01.wav : [ (len=81667, dtype=float32, shape=(81667,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-08-01-02-01-01.wav : [ (len=77989, dtype=float32, shape=(77989,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-08-01-02-02-01.wav : [ (len=72102, dtype=float32, shape=(72102,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-08-02-02-02-01.wav : [ (len=72103, dtype=float32, shape=(72103,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-03-01-01-01-01.wav : [ (len=76517, dtype=float32, shape=(76517,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-05-02-02-01-01.wav : [ (len=91231, dtype=float32, shape=(91231,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-06-02-01-02-01.wav : [ (len=93439, dtype=float32, shape=(93439,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-01-01-01-01-01.wav : [ (len=72838, dtype=float32, shape=(72838,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-02-01-02-02-01.wav : [ (len=76517, dtype=float32, shape=(76517,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-03-01-01-02-01.wav : [ (len=76517, dtype=float32, shape=(76517,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-03-01-02-01-01.wav : [ (len=77988, dtype=float32, shape=(77988,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-03-02-01-01-01.wav : [ (len=80931, dtype=float32, shape=(80931,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-05-01-02-01-01.wav : [ (len=77253, dtype=float32, shape=(77253,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-03-02-01-02-01.wav : [ (len=80195, dtype=float32, shape=(80195,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-06-02-02-01-01.wav : [ (len=87553, dtype=float32, shape=(87553,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-07-01-02-02-01.wav : [ (len=84610, dtype=float32, shape=(84610,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-05-01-01-02-01.wav : [ (len=86817, dtype=float32, shape=(86817,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-08-01-01-02-01.wav : [ (len=72102, dtype=float32, shape=(72102,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-02-02-02-01-01.wav : [ (len=92703, dtype=float32, shape=(92703,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-05-01-01-01-01.wav : [ (len=85346, dtype=float32, shape=(85346,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-04-01-01-01-01.wav : [ (len=84610, dtype=float32, shape=(84610,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-06-02-02-02-01.wav : [ (len=86082, dtype=float32, shape=(86082,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-02-02-01-01-01.wav : [ (len=81667, dtype=float32, shape=(81667,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-07-02-02-01-01.wav : [ (len=89025, dtype=float32, shape=(89025,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-03-02-02-01-01.wav : [ (len=86817, dtype=float32, shape=(86817,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-07-02-01-01-01.wav : [ (len=94910, dtype=float32, shape=(94910,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-06-01-02-01-01.wav : [ (len=75781, dtype=float32, shape=(75781,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-08-02-02-01-01.wav : [ (len=77253, dtype=float32, shape=(77253,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-06-01-01-02-01.wav : [ (len=80196, dtype=float32, shape=(80196,)), sample_rate=22050 ],
# ./RAVDESS/Actor_01/03-01-04-02-01-02-01.wav : [ (len=81667, dtype=float32, shape=(81667,)), sample_rate=22050 ]

# %%
for root, dirs, files in os.walk("./test"):
    # Exclude directories early
    print(dirs)
    print([os.path.join(root, f) for f in files])
    print(root)
# Out:
# ['test2', 'test3']
# ['./test/f3t1.txt', './test/f2t1.txt', './test/f4t1.txt', './test/f1t1.txt']
# ./test
# ['test2-2']
# ['./test/test2/f3t2.txt', './test/test2/f4t2.txt', './test/test2/f2t2.txt', './test/test2/f1t2.txt']
# ./test/test2
# []
# ['./test/test2/test2-2/f2t2-2.txt', './test/test2/test2-2/f4t2-2.txt', './test/test2/test2-2/f3t2-2.txt', './test/test2/test2-2/f1t2-2.txt']
# ./test/test2/test2-2
# []
# ['./test/test3/f3t3.txt', './test/test3/f2t3.txt', './test/test3/f4t3.txt', './test/test3/f1t3.txt']
# ./test/test3
